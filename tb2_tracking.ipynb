# %% [markdown]
# #ORTAM HAZIRLIĞI

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Bayraktar_TB2_Track
# Out:
# /content/drive/MyDrive/Bayraktar_TB2_Track

# %%
# !pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/78.2 GB disk)

# %% [markdown]
# # TRAİN // EĞİTİM

# %%
# !unzip data/dataset.zip -d ./data
# Out:
# Archive:  data/dataset.zip
#    creating: ./data/dataset/
#    creating: ./data/dataset/test/
#    creating: ./data/dataset/test/images/
#   inflating: ./data/dataset/test/images/1008_jpg.rf.23d7659a1e7cc0bfaf4e3467f93f4498.jpg
#   inflating: ./data/dataset/test/images/1014_jpg.rf.cc92421ca1f7b25f749bd92ef037cd36.jpg
#   inflating: ./data/dataset/test/images/807_jpg.rf.d28e1f2c872ea74664f7f8fbf9593ea8.jpg
#   inflating: ./data/dataset/test/images/808_jpg.rf.91115362ce072396a3f52257c057553d.jpg
#   inflating: ./data/dataset/test/images/812_jpg.rf.9efe569acf0884c5f43baa444e6f64df.jpg
#   inflating: ./data/dataset/test/images/828_jpg.rf.8f57db5a5eec92d13849993171616d32.jpg
#   inflating: ./data/dataset/test/images/829_jpg.rf.e535bd37fab433ee0696edfc7c70e069.jpg
#   inflating: ./data/dataset/test/images/833_jpg.rf.3bc526e063a3656769ce687b086a74a2.jpg
#   inflating: ./data/dataset/test/images/867_jpg.rf.0580b5a373f731c9f49a6c7e7feb61b6.jpg
# ...

# %%
# !yolo track train data=/content/drive/MyDrive/Bayraktar_TB2_Track/data/data.yaml model=yolov8n.pt epochs=150 imgsz=640 device=0 batch=12 workers=8 name=tb2_tracking amp=False
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # TEST // PREDİCT

# %%
# !yolo track model=/content/drive/MyDrive/Bayraktar_TB2_Track/tb2_tracking4/weights/last.pt source="https://youtu.be/nH4RvvFrJSg?si=Rk9j2bSU8gdFJoVk"
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#
# 1/1: https://youtu.be/nH4RvvFrJSg?si=Rk9j2bSU8gdFJoVk... Success ✅ (2554 frames of shape 1920x1080 at 30.00 FPS)
#
# 0: 384x640 1 bayraktar_tb2, 572.8ms
# 0: 384x640 1 bayraktar_tb2, 11.9ms
# 0: 384x640 1 bayraktar_tb2, 8.7ms
# 0: 384x640 1 bayraktar_tb2, 6.5ms
# 0: 384x640 1 bayraktar_tb2, 6.5ms
# 0: 384x640 1 bayraktar_tb2, 6.4ms
# 0: 384x640 1 bayraktar_tb2, 13.8ms
# 0: 384x640 1 bayraktar_tb2, 6.5ms
# 0: 384x640 1 bayraktar_tb2, 6.8ms
# 0: 384x640 1 bayraktar_tb2, 14.9ms
# 0: 384x640 1 bayraktar_tb2, 6.7ms
# 0: 384x640 1 bayraktar_tb2, 7.1ms
# 0: 384x640 1 bayraktar_tb2, 8.0ms
# 0: 384x640 1 bayraktar_tb2, 8.0ms
# 0: 384x640 1 bayraktar_tb2, 6.5ms
# 0: 384x640 1 bayraktar_tb2, 6.6ms
# 0: 384x640 1 bayraktar_tb2, 8.1ms
# 0: 384x640 1 bayraktar_tb2, 10.6ms
# 0: 384x640 1 bayraktar_tb2, 6.8ms
# ...
